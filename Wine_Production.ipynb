# %% [markdown]
# # Analysis of Wine Production

# %% [markdown]
# ### Content
# + Introduction
# + Data description and objectives
# + Data acquisiton, manipulation and validation
# + Data analysis and visualization
# + Conclusion

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Source:(https://www.kaggle.com/zynicide/wine-reviews)

# %% [markdown]
# Wine is an alcoholic beverage produced by the fermentation of the juice of fruits, usually grapes, although other fruits such as plum, banana, elderberry or blackcurrant may also be fermented and used to obtain products named "wine". In this short article the word "wine" refers to the product obtained from grapes. This product is probably the most ancient fermented beverage and was mentioned in the Bible and in other documents from Asiatic peoples. Exactly where wine was first made is still unclear. It could have been anywhere in the vast region, stretching from Portugal to Central Asia, where wild grapes grow.

# %% [markdown]
# Many consumers are interested in the quality and variety of wine. But also by manufacturer, country, year, description on the cover, popularity and, of course, price. In this analysis, you will find out if there is any benefit to wine, how many percent of the population consumes and which country is leading in the production of this drink.

# %% [markdown]
# ## 2. Data description and objectives

# %% [markdown]
#  As we know, wine is one of the most relevant and at the same time popular alcoholic drinks in the world. No matter how many years have passed, wine remains with the same great demand as before.
#
# In this analysis based on wine production, you will find out how popular in the world,usually who uses, how much it affects to  health, what is the highest price of this product and what are the ratings of manufacturers.
#
#
# #### The main questions:
#
# •Country – country of production
# •Description  - short description,composition of wine
# •Designation – how called brand
# •Points – points of wine tasting
# •Price – price for one bottle of wine
# •Province  - produced province
# •Region_1, region_2 – produced
# •Variety – other type of this wine
# •Winery – production
# •Taster_name - sommelier, person who tested of wine
# •Title - full name of the wine
#
#
#
# #### The main questions about this dataset:
# 1.Analyze about how many percent of the total population in the world consume wine
# 2.Analyze about wine healthy given its popularity? How much wine can affect the human body?
# 3.Analyze about which country is popular in wine production?
# 4.Analyze about what properties each of the types of wine has, which one is more popular?
# 5.Analyze about how much wine is more expensive than other alcoholic beverages?

# %% [markdown]
# As you can see, in this table  provides information on which countries out of 11 leading, how many liters of wine are produced per year. I added this table in order to further have an idea with which countries we will work.

# %% [markdown]
# If you believe the statistics, then France is the most engaged in wine production with the result of 5.5 million liters ahead of Italy by only 200,000 liters, followed by Spain, the USA and Argentina. Portugal will finished the top 11 with a score of about 600,000

# %%
df = pd.DataFrame([[1,'France','5.329.449'],
                  [2,'Italy', '5.056.648'],
                  [3,'Spain', '3.934.140'],
                  [4,'USA', '2.232.000'],
                  [5,'Argentina', '1.564.000'],
                  [6,'China', '1.300.000'],
                  [7,'Australia', '1.274.000'],
                  [8,'South Africa', '1.157.895'],
                  [9,'Germany', '1.014.700'],
                  [10,'Chile', '788.851'],
                  [11,'Portugal', '576.500']], 
columns=['Numb','Country', 'Count_of_the_produce'])
print(df)
# Out:
#     Numb       Country Count_of_the_produce
# 0      1        France            5.329.449
# 1      2         Italy            5.056.648
# 2      3         Spain            3.934.140
# 3      4           USA            2.232.000
# 4      5     Argentina            1.564.000
# 5      6         China            1.300.000
# 6      7     Australia            1.274.000
# 7      8  South Africa            1.157.895
# 8      9       Germany            1.014.700
# 9     10         Chile              788.851
# 10    11      Portugal              576.500

# %%
#Thus, we go to the table from the dataset given to us. Source:(https://www.kaggle.com/zynicide/wine-reviews)

# %%
import numpy as np 
import pandas as pd 
md = pd.read_csv('winemag-data-130k-v2.csv')
cr = pd.read_csv('winemag-data_first150k.csv')

# %%
md.head(20)
# Out:
#     Unnamed: 0    country                                        description  \
# 0            0      Italy  Aromas include tropical fruit, broom, brimston...
# 1            1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2            2         US  Tart and snappy, the flavors of lime flesh and...
# 3            3         US  Pineapple rind, lemon pith and orange blossom ...
# 4            4         US  Much like the regular bottling from 2012, this...
# 5            5      Spain  Blackberry and raspberry aromas show a typical...
# 6            6      Italy  Here's a bright, informal red that opens with ...
# 7            7     France  This dry and restrained wine offers spice in p...
# 8            8    Germany  Savory dried thyme notes accent sunnier flavor...
# 9            9     France  This has great depth of flavor with its fresh ...
# 10          10         US  Soft, supple plum envelopes an oaky structure ...
# ...

# %%
cr.head(20)
# Out:
#     Unnamed: 0 country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 1            1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2      US  Mac Watson honors the memory of a wine once ma...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 4            4  France  This is the top wine from La Bégude, named aft...
# 5            5   Spain  Deep, dense and pure from the opening bell, th...
# 6            6   Spain  Slightly gritty black-fruit aromas include a s...
# 7            7   Spain  Lush cedary black-fruit aromas are luxe and of...
# 8            8      US  This re-named vineyard was formerly bottled as...
# 9            9      US  The producer sources from two blocks of the vi...
# 10          10   Italy  Elegance, complexity and structure come togeth...
# 11          11      US  From 18-year-old vines, this supple well-balan...
# ...

# %%
#For the next step, we don't need some columns and we can drop these columns.In the first table I need to drop taster_name, taster_twitter_handle,region_2,points. Because these columns is not necessary.

# %%
md = md.drop('taster_twitter_handle',axis=1)
md = md.drop('region_2',axis=1)
md = md.drop('taster_name',axis=1)
md = md.drop('points',axis=1)

# %%
md.head(20)

# %%
# By the way, in the second table I need to drop region_2,points. Because these columns is not necessary.

# %%
cr = cr.drop('region_2',axis=1)
cr = cr.drop('points',axis=1)

# %%
cr.head(20)
